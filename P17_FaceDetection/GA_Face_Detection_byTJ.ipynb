# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#If Run from Googlr Colaboratory, uncomment the following:
#!gdown --id 1PAJ48UhCb-vLnMk-Frl91mwoklxZ8hwu

# %%
#!gdown --id 1ka-Nxu2s6yHf1nDqAekF3fUGI8uMDv7Z

# %%
#from google.colab.patches import cv2_imshow

# %%
# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# To capture video from webcam. 
#cap = cv2.VideoCapture(0)
# To use a video file as input 
cap = cv2.VideoCapture('Face_Detcn_Rec_Vid.mp4')

while True:
    # Read the frame
    ret, frame = cap.read()
    count = 0
    # Convert to grayscale
    gray = cv2.cvtColor( frame, cv2.COLOR_BGR2GRAY )
    # Detect the faces
    faces = face_cascade.detectMultiScale( gray,1.1,5)
    # Draw the rectangle around each face
    for (x, y, w, h) in faces:
        count = count+1
        cv2.rectangle( frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
    # Display
    count = str(count)
    font = cv2.FONT_HERSHEY_SIMPLEX
    org = ( 0, 185)
    fontScale = 1
    color = (0, 0, 255)
  
    # Line thickness of 2 px
    thickness = 1
    cv2.putText( frame , count, org, font, fontScale,
                  color, thickness, cv2.LINE_AA, False )
    cv2.imshow("Frame_in_Video", frame )
    # Stop if escape key is pressed
    k = cv2.waitKey(30) & 0xff
    if k==27:
        break
# Release the VideoCapture object
cap.release()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#The above Code captures Front Faces from a Video.
